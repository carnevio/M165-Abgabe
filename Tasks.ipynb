# %% [markdown]
# # M165 Aufgabe

# %% [markdown]
# ## Imports

# %%
from dotenv import load_dotenv
import os
from pymongo import MongoClient

# %% [markdown]
# ## Connection

# %% [markdown]
# ## 1. Setup

# %%
load_dotenv()
connection_string = os.getenv("MONGODB_URI")
client = MongoClient(connection_string)

# %% [markdown]
# ### 1. Erkläre die Abkürzung ODM und welche Funktion ODM wahrnimmt.

# %% [markdown]
# ### 2. Richte dein System so ein, dass du über Python eine Verbindung zur Datenbank herstellen kannst. Erstelle dazu ein kleines Testprogramm.

# %%
load_dotenv()
connection_string = os.getenv("MONGODB_URI")
client = MongoClient(connection_string)

print(client.server_info())
# Out:
# {'version': '8.0.20', 'gitVersion': '28927c60881a488fcbc5fd4d925b410f33258827', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 20, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1776674283, 389), 'signature': {'hash': b'\x08E\xde\x06\xf8\xbc\x7f\x86\xd6\x940\xae\xd7I\xaa\x11\xeaF\xd3\xb3', 'keyId': 7592297170418532366}}, 'operationTime': Timestamp(1776674283, 389)}

# %% [markdown]
# ## 2. DB, Collection, Document

# %% [markdown]
# ### 1. Wenn die Applikation gestartet wird, werden alle Datenbanken nach diesem Muster aufgelistet:

# %%
while True:
	databases = client.list_database_names()
	if not databases:
		print("No Database")
		input("\nPress any button to return")
		continue
	print("Databases")
	for db in databases:
		print(f" - {db}")

	while True:
		selected_db = input("\nSelect Database: ")
		if selected_db not in databases:
			print("Database not found. Bitte erneut versuchen.")
			continue
		break

	print(f"\n{selected_db}\n")
	db = client[selected_db]
# Out:
# Databases
#  - media
#  - restaurants
#  - sample_mflix
#  - test
#  - admin
#  - local
# Database not found. Bitte erneut versuchen.
# Database not found. Bitte erneut versuchen.
# Database not found. Bitte erneut versuchen.
# Database not found. Bitte erneut versuchen.
# Database not found. Bitte erneut versuchen.
# Database not found. Bitte erneut versuchen.
# Database not found. Bitte erneut versuchen.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#       9 	print(f" - {db}")
#      11 while True:
# ---> 12 	selected_db = input("\nSelect Database: ")
#      13 	if selected_db not in databases:
#      14 		print("Database not found. Bitte erneut versuchen.")
#
# File ~/Library/CloudStorage/OneDrive-Personal/Nevio-Oiven/Schule/Berufsfachschule/2.LJ/2.Semester/M165/Aufgaben/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/Library/CloudStorage/OneDrive-Personal/Nevio-Oiven/Schule/Berufsfachschule/2.LJ/2.Semester/M165/Aufgaben/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
